# %%
import pandas as pd

# %% [markdown]
# 2 main datatypes:
# - series: array alike - 1-dimensional
# - dataFrame: object alike - 2-dimensional

# %%
# Series
series = pd.Series(["BMW", "Toyota", "Honda"])
colors = pd.Series(["blue", "red", "green"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors
# Out:
# 0     blue
# 1      red
# 2    green
# dtype: object

# %%
car = pd.DataFrame({"Manufacturer": series, "Color": colors})

# %%
car
# Out:
#   Manufacturer  Color
# 0          BMW   blue
# 1       Toyota    red
# 2        Honda  green

# %%
# Import data
car_sales = pd.read_csv("./49 - car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Anatomy of a DataFrame
# ![.](./49%20-%20pandas-anatomy-of-a-dataframe.png)

# %%
# Export a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# give statistic info about NUMERIC columns
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# info = index + dtype
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].median()
# Out:
# 57369.0

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## View & Select Data

# %%
# returm the first 5 row (default)
car_sales.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
# return the last 5 rows (default)
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## .loc & .iloc
# - .loc: refer to index
# - .iloc: refer to position
#
# - both can use slicing [:2]

# %%
# .loc (location) & .iloc
animals = pd.Series(['bird', 'dog', 'cat', 'frog',' horse', 'pig', 'ox'], index=[3,2,3,9,1,2,5])

# %%
animals.loc[3]
# Out:
# 3    bird
# 3     cat
# dtype: object

# %%
animals.loc[9]
# Out:
# 'frog'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'frog'

# %%
animals.iloc[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 animals.iloc[9]
#
# File d:\learning\ml\ztm\env\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\learning\ml\ztm\env\Lib\site-packages\pandas\core\indexing.py:1753, in _iLocIndexer._getitem_axis(self, key, axis)
#    1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
# -> 1753 self._validate_integer(key, axis)
#    1755 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
animals.iloc[:3]
# Out:
# 3    bird
# 2     dog
# 3     cat
# dtype: object

# %%
animals.loc[:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 animals.loc[:3]
#
# File d:\learning\ml\ztm\env\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\learning\ml\ztm\env\Lib\site-packages\pandas\core\indexing.py:1412, in _LocIndexer._getitem_axis(self, key, axis)
#    1410 if isinstance(key, slice):
#    1411     self._validate_key(key, axis)
# -> 1412     return self._get_slice_axis(key, axis=axis)
#    1413 elif com.is_bool_indexer(key):
#    1414     return self._getbool_axis(key, axis=axis)
#
# ...

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.Colour[:3]
# Out:
# 0    White
# 1      Red
# 2     Blue
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# ## Comparing & Plotting data

# %%
# Comparing 2 cols
pd.crosstab(car_sales["Make"], car_sales["Price"], car_sales["Odometer (KM)"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Comparing 2 cols
# ----> 2 pd.crosstab(car_sales["Make"], car_sales["Price"], car_sales["Odometer (KM)"])
#
# File d:\learning\ml\ztm\env\Lib\site-packages\pandas\core\reshape\pivot.py:688, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     685     raise ValueError("aggfunc cannot be used without values.")
#     687 if values is not None and aggfunc is None:
# --> 688     raise ValueError("values cannot be used without an aggfunc.")
#     690 if not is_nested_list_like(index):
#     691     index = [index]
#
# ValueError: values cannot be used without an aggfunc.

# %%
pd.crosstab(car_sales["Make"], car_sales["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
# Comparing multiple cols
car_sales.groupby(["Make", "Colour", "Doors"]).mean(numeric_only=True)
# Out:
#                      Odometer (KM)
# Make   Colour Doors
# BMW    Black  5            11179.0
# Honda  Blue   4            50218.0
#        Red    4            87899.0
# Nissan White  4           122347.5
# Toyota Blue   3            32549.0
#        Green  4            99213.0
#        White  4           105021.5

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales["Odometer (KM)"].plot(legend=True)
# Out:
# <Axes: >

# %%
car_sales["Doors"].plot(legend=True)
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist(legend=True)
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[$,.]", '', regex=True).astype(int)
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales_missing = pd.read_csv("./")
