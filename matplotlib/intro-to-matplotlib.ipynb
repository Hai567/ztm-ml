# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Matplotlib Workflow

# %% [markdown]
# ![.](./matplotlib-workflow.png)

# %%
plt.plot()
# This is our figure
# Out:
# []

# %%
plt.plot([1,2,3,4,5])

# %%
x = [1,2,3,4,5]
y=[11,22,33,44,55]
plt.plot(x,y) 
# Stateless way (API) Not recommended

# %%
# 1st method
fig = plt.figure() # Create a figure
ax = fig.add_subplot() # Create some axes
plt.show()

# Exactly the same with plt.plot()

# %%
# 2nd method
fig = plt.figure() # create a figure
ax = fig.add_axes([0.2, 0.2 ,0.2, 0.2 ]) # size 
ax.plot(x, y) # add some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
fig.add_axes([1,1,1,1])
fig.add_axes([2,2,2,2])
ax.plot(x, y)

# %% [markdown]
# ## 2. Matplotlib Anatomy

# %% [markdown]
# ![.](./matplotlib-anatomy.png)
#
# - Axeses are the subplot of the figure

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. import matplotlib and get ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y=[11,22,33,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10)) # width, height

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Example plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("./example_plot.png")

# %% [markdown]
# ## 3. Different types of plot
# - Line plot
# - Scatter plot
# - Bar plot
# - Histogram
# - Subplot

# %%
# Making figures with NumPy arrays
x = np.linspace(0, 10, 100) # start, stop, number of data
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ### Line plot

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**4)

# %% [markdown]
# ### Scatter plot

# %%
fig, ax = plt.subplots()
ax.scatter(x, x**4)
fig.show()
# Out:
# C:\Users\ducha\AppData\Local\Temp\ipykernel_12580\2121439408.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Another scatter
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %% [markdown]
# ### Bar plot

# %%
prices = {"Almond": 10, "Peanut": 8, "Cashew": 12}
fig, ax = plt.subplots()
ax.set(title="Nuts' prices", ylabel="Price", xlabel="Nut")
ax.bar(x=prices.keys(), height=prices.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Bar Horizontal

# %%
fig, ax = plt.subplots()
ax.barh(y=prices.keys(), width=prices.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram

# %%
x = np.random.randn(10000) # Random distribution
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([   7.,   79.,  390., 1347., 2613., 2858., 1843.,  690.,  151.,
#           22.]),
#  array([-3.99019606, -3.22264573, -2.45509541, -1.68754508, -0.91999476,
#         -0.15244443,  0.61510589,  1.38265622,  2.15020654,  2.91775687,
#          3.68530719]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Subplots in a figure

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))

ax1.plot(x, x/2)
ax2.plot(x, x**2)
ax3.bar(x=prices.keys(), height=prices.values())
ax4.barh(y=prices.keys(), width=prices.values())
ax5.hist(x)
ax6.scatter(x, x**2)

# %%
# 2nd way of subplot
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))
ax[0,0].scatter(x, x/2)
ax[1,1].hist(x)
# Out:
# (array([   7.,   79.,  390., 1347., 2613., 2858., 1843.,  690.,  151.,
#           22.]),
#  array([-3.99019606, -3.22264573, -2.45509541, -1.68754508, -0.91999476,
#         -0.15244443,  0.61510589,  1.38265622,  2.15020654,  2.91775687,
#          3.68530719]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 4. Plotting from pandas DataFrame

# %%
np.cumsum() # Cummulative sum
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 np.cumsum() # Cummulative sum
#
# TypeError: cumsum() missing 1 required positional argument: 'a'

# %% [markdown]
# ![.](./cumsum-explained.png)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2025", periods=1000))
ts[:10]
# Out:
# 2025-01-01    0.619813
# 2025-01-02   -1.036397
# 2025-01-03   -1.093479
# 2025-01-04    1.666004
# 2025-01-05    2.031099
# 2025-01-06    0.874384
# 2025-01-07   -0.317840
# 2025-01-08   -0.946965
# 2025-01-09    2.710049
# 2025-01-10   -0.844218
# Freq: D, dtype: float64

# %%
ts_cs = ts.cumsum()
ts_cs[:10]
# Out:
# 2025-01-01    0.619813
# 2025-01-02   -0.416584
# 2025-01-03   -1.510063
# 2025-01-04    0.155941
# 2025-01-05    2.187040
# 2025-01-06    3.061425
# 2025-01-07    2.743585
# 2025-01-08    1.796620
# 2025-01-09    4.506669
# 2025-01-10    3.662450
# Freq: D, dtype: float64

# %%
ts_cs.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

car_sales = pd.read_csv("../pandas/49 - car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[$,.]", "", regex=True).astype(int)
car_sales["Sold Date"] = pd.date_range("2/5/2025", periods=10)

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sold Date
# 0  Toyota  White         150043      4   400000 2025-02-05
# 1   Honda    Red          87899      4   500000 2025-02-06
# 2  Toyota   Blue          32549      3   700000 2025-02-07
# 3     BMW  Black          11179      5  2200000 2025-02-08
# 4  Nissan  White         213095      4   350000 2025-02-09
# 5  Toyota  Green          99213      4   450000 2025-02-10
# 6   Honda   Blue          45698      4   750000 2025-02-11
# 7   Honda   Blue          54738      4   700000 2025-02-12
# 8  Toyota  White          60000      4   625000 2025-02-13
# 9  Nissan  White          31600      4   970000 2025-02-14

# %%
car_sales["Total sales"]=car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sold Date  Total sales
# 0  Toyota  White         150043      4   400000 2025-02-05       400000
# 1   Honda    Red          87899      4   500000 2025-02-06       900000
# 2  Toyota   Blue          32549      3   700000 2025-02-07      1600000
# 3     BMW  Black          11179      5  2200000 2025-02-08      3800000
# 4  Nissan  White         213095      4   350000 2025-02-09      4150000
# 5  Toyota  Green          99213      4   450000 2025-02-10      4600000
# 6   Honda   Blue          45698      4   750000 2025-02-11      5350000
# 7   Honda   Blue          54738      4   700000 2025-02-12      6050000
# 8  Toyota  White          60000      4   625000 2025-02-13      6675000
# 9  Nissan  White          31600      4   970000 2025-02-14      7645000

# %%
car_sales.plot(x="Sold Date", y="Total sales")
# Out:
# <Axes: xlabel='Sold Date'>

# %%
car_sales.plot(x="Sold Date", y="Total sales", kind="scatter")
# Out:
# <Axes: xlabel='Sold Date', ylabel='Total sales'>

# %%
car_sales.plot.barh(x="Make", y="Odometer (KM)")
# Out:
# <Axes: ylabel='Make'>

# %%
x = np.random.rand(10, 4)
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.814639  0.512976  0.268719  0.599736
# 1  0.452410  0.998448  0.836197  0.656972
# 2  0.771862  0.105322  0.466965  0.068600
# 3  0.129165  0.444602  0.543578  0.838230
# 4  0.562546  0.700005  0.137429  0.596072
# 5  0.914309  0.445582  0.749818  0.686884
# 6  0.239457  0.856373  0.674403  0.819659
# 7  0.993770  0.512820  0.131125  0.956727
# 8  0.690575  0.895280  0.206219  0.306137
# 9  0.808346  0.572324  0.578190  0.809435

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind="barh")
# Out:
# <Axes: >

# %%
df.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../pandas/49 - car-sales.csv')

# Get the value counts for the 'Make' column
# .sort_values(ascending=False) ensures the bars are sorted by count
make_counts = df['Make'].value_counts().sort_values(ascending=False)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 6), squeeze=True) # Set a good figure size# Add grid lines for the y-axis

ax[0].pie(make_counts)
ax[1].bar(x=make_counts.index, height=make_counts.values)
# Out:
# <BarContainer object of 4 artists>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=2)
# car_sales["Odometer (KM)"].plot(kind="bar", bin=10) # Doesn't have bins option
# Out:
# <Axes: ylabel='Frequency'>

# %%
health_disease = pd.read_csv("./90 - heart-disease.csv")
health_disease.plot.hist(subplots=True, figsize=(10, 40))  # not ideal
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### PyPlot vs matplotlib OO method comparison
# - When plotting something quickly, it's ok to use PyPlot method
# - When plotting advanced things, use the OO method

# %%
over_50 = health_disease[health_disease['age'] > 50]
over_50[:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind="scatter", x='age', y="chol", c="target", figsize=(10,6))
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# OOP mixed with PyPlot
fig, ax = plt.subplots()
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax)# difference is here
ax.set_xlim([0, 100])
# Out:
# (0.0, 100.0)

# %%
## OOP method from scratch
fig, (ax0, ax1) = plt.subplots(
    nrows=2, 
    ncols=1, 
    figsize=(10,10),
    sharex=True
    )

# Plotting the data
scatter = ax0.scatter(
    x=over_50["age"],
    y=over_50["chol"], 
    c=over_50['target']
    )
thalach = ax1.scatter(
    x=over_50["age"],
    y=over_50["thalach"],
    c=over_50["target"]
)

# Customize the plot
ax0.set(
    title="Heart Disease and Cholesterol Level",
    ylabel="Cholesterol"
)
ax1.set(
    title="Heart Disease and Highest Heart Rate Level",
    xlabel="Age",
    ylabel="Highest Heart Rate"
)

# Add a legend
# Unpacking (Destructuring)
ax0.legend(*scatter.legend_elements(), title="Target")
ax1.legend(*thalach.legend_elements(), title="Target")

# Add a horizontal line
ax0.axhline(y=over_50["chol"].mean(), linestyle="-.")
# 1. Calculate the 25th (Q1) and 75th (Q3) percentiles
q1 = over_50["thalach"].quantile(0.25)
q3 = over_50["thalach"].quantile(0.75)
ax1.axhspan(
    ymin=q1,  
    ymax=q3,
    alpha=0.2,
    color="red"
    )

# Add title to the figure
fig.suptitle("Heart Disease Analysis", fontweight="bold", fontsize="20")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
type(over_50["thalach"])
# Out:
# pandas.core.series.Series
